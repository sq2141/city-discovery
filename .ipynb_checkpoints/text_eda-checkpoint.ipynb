# %%
import pandas as pd
import numpy as np

# %%
cities_geo_df = pd.read_csv('cities_geo_df.csv')
cities_geo_df.head()
# Out:
#    Unnamed: 0      Country       City  \
# 0           0  Afghanistan      Herat
# 1           1  Afghanistan      Kabul
# 2           2  Afghanistan  Jalalabad
# 3           3  Afghanistan   Kandahar
# 4           4  Afghanistan     Kunduz
#
#                                           Understand  \
# 0  Herat is the second largest city in Afghanista...
# 1  Kabul is a very historic city of the region th...
# 2                                                NaN
# 3  Kandahār or Qandahār (Pashto: کندهار ) (Persia...
# 4                                                NaN
#
#                                               Get in  \
# 0  The Herat International Airport is situated 15...
# 1  By plane[edit] Kabul International Airport (IA...
# 2  Jalalabad is on the major highway that links K...
# 3  By plane[edit] Kandahar International Airport ...
# 4  Most visitors will arrive by road from Pol-e K...
#
#                                           Get around  \
# ...

# %%
cities_geo_df[cities_geo_df['Lat']==np.nan]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Country, City, Understand, Get in, Get around, See, Do, Buy, Eat, Sleep, Cope, Stay safe, Get out, City_alternative, Lat, Lon, Alt]
# Index: []
