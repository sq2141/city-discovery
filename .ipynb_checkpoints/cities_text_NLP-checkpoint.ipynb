# %%
import pandas as pd
import numpy as np
import re
import ast
import seaborn as sns
import matplotlib.pyplot as plt
import time
from IPython.display import clear_output
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cosine
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
# %matplotlib inline  

import warnings

with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)
    import nltk
    from nltk.tokenize import RegexpTokenizer
    from nltk.stem.wordnet import WordNetLemmatizer
    from nltk.corpus import stopwords, words
    from nltk import FreqDist

    import gensim
    from gensim import corpora, models, similarities
    import pyLDAvis
    import pyLDAvis.gensim

# %%
cities = pd.read_csv('cities_geo2_df.csv', index_col=0)

# Reset index
cities = cities.reset_index()
cities.drop(['index'], axis=1, inplace=True)

# %%
#cities.head()

# %%
# # Run once
# nltk.download('wordnet')
# nltk.download('stopwords')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('words')

# %%
tokenizer = RegexpTokenizer(r'\w+') # retains alphanumeric character
lmtzr = WordNetLemmatizer()
cached_stop_words = stopwords.words("english")

# %%
def lemmatize_dropstop_words(text): 
    print(text)
    clear_output(wait=True)
    return [lmtzr.lemmatize(word) for word in text if 
            (len(word)>2) and 
            (lmtzr.lemmatize(word) not in cached_stop_words) and 
            (word in words.words())
            ]

def remove_num(text): 
    return re.sub("\d+", " ", text)

# %%
cities = cities.replace(np.nan, '', regex=True)

# %%
# Add my stop words from txt file
my_stop_words = np.genfromtxt('my_stop_words.txt',dtype='str', delimiter=', ').tolist()
cached_stop_words.extend(my_stop_words)

# %%
# Read
REFILTER_WORDS = False

# %%
if REFILTER_WORDS == True:
    cities['See_tokens'] = cities['See'].str.lower().apply(tokenizer.tokenize).apply(lemmatize_dropstop_words)

# %%
if REFILTER_WORDS == True:
    cities['Do_tokens'] = cities['Do'].str.lower().apply(tokenizer.tokenize).apply(lemmatize_dropstop_words)
        
    # Pool tokens
    def pool_tokens(row):
        return row['See_tokens']+row['Do_tokens']

    cities['Pooled_tokens'] = cities.apply(pool_tokens, axis=1)

# %%
if REFILTER_WORDS == True:
    cities['Understand_tokens'] = cities['Understand'].str.lower().apply(tokenizer.tokenize).apply(lemmatize_dropstop_words)

# %%
if REFILTER_WORDS == True:
    cities['Stay safe_tokens'] = cities['Stay safe'].str.lower().apply(tokenizer.tokenize).apply(lemmatize_dropstop_words)

# %%
if REFILTER_WORDS == False:
    cities = pd.read_csv('cities_text_processed_df.csv', index_col = 0)

# %%
# If reloaded from .csv file, convert string to list
if type(cities['Pooled_tokens'][0])==str:
    cities['Pooled_tokens'] = cities['Pooled_tokens'].apply(ast.literal_eval)

# %%
# Most common words
words = []
for sublist in cities['Pooled_tokens']:
    for item in sublist:
        words.append(item)
        
fdist = FreqDist(words)
fdist.most_common(20)
# Out:
# [('museum', 9558),
#  ('park', 7930),
#  ('art', 3857),
#  ('free', 3827),
#  ('old', 3576),
#  ('temple', 3433),
#  ('well', 3299),
#  ('center', 3062),
#  ('world', 2996),
#  ('town', 2972),
#  ('festival', 2790),
#  ('road', 2779),
#  ('bus', 2682),
#  ('river', 2681),
#  ('small', 2613),
#  ('church', 2584),
#  ('walk', 2574),
#  ('station', 2569),
#  ('local', 2454),
#  ('great', 2406)]

# %%
# Manual clean up some city names (European cities with alternate spelling) or duplicate city names
replacements = [
    ['Germany', 'München', 'Munich'],
    ['Czech Republic', 'Praha', 'Prague'],
    ['Italy', 'Florencia', 'Florence'],
    ['Italy', 'Roma', 'Rome'],
    ['Portugal', 'Lisboa', 'Lisbon'],
    ['Spain', 'Sevilla', 'Seville'],
    ['Greece', 'Athinai', 'Athens'],
    ['Poland', 'Wroclaw', 'Warsaw'],
    ['Italy', 'Milano', 'Milan'],
    ['Austria', 'Wien', 'Vienna'],
    
    ['Canada', 'London', 'London (C)'],
    ['Canada', 'Cambridge', 'Cambrdige (C)'],
    ['Argentina', 'Cordoba', 'Cordoba (A)'],
    ['United States', 'Cambridge', 'Cambrdige (US)'],
    ['United States', 'Vancouver', 'Vancouver (US)'],
    ['United States', 'Saint Petersburg', 'Saint Petersburg (US)'],
    ['United Kingdom', 'Newark', 'Newark (UK)'],
    ['United Kingdom', 'Rochester', 'Rochester (UK)']
]

for row in replacements:
    cities.loc[(cities.Country==row[0]) & (cities.City==row[1]), 'City']=row[2]

# %%
#cities[cities.duplicated(subset='City', keep=False)==True]

# %%
# Save cities with final index
cities.to_csv('cities_text_processed_df.csv')

# %%
# Join tokens to one string to be compatible w/ sklearn models
def tokens_to_str(tokens):
    return ' '.join(tokens)

cities['Pooled_string'] = cities['Pooled_tokens'].apply(tokens_to_str)

# %% [markdown]
# # Vectorize text

# %%
# Add some more geography-referencing words that escaped the english stopwords dict
stoplist2 = ['new','york']

def stop_words2(tokens):
    newlist = []
    for word in tokens:
        if word not in stoplist2:
            newlist.append(word)
    return newlist

# %%
# Final level of stop words
cities['Pooled_tokens2'] = cities['Pooled_tokens'].apply(stop_words2)
cities['Pooled_string2'] = cities['Pooled_tokens2'].apply(tokens_to_str)

# %%
# Initialize Model
vec=TfidfVectorizer(min_df=3)

# %%
# CountVec fit to Bag of Words
vec1 = vec.fit_transform(cities['Pooled_string2'])

# %%
# Cosine similarity matrix
cosims_mat = 1-pairwise_distances(vec1.A, metric="cosine")
cosims_mat

cosims_df = pd.DataFrame(cosims_mat)
cosims_df.head()

# Save
cosims_df.to_csv('data/cos_sims.csv')

# Save stacked version
cosims_stacked = cosims_df.stack()
cosims_stacked.to_csv('data/cos_sims_stacked.csv')

# %%
# Visualize cosims matrix

plt.figure(figsize=(10,10))
sns.heatmap(cosims_stacked.values,cmap='Reds')

# %%
# Test output cities given user input

input_city = 'London'
input_index = [cities[cities['City']==input_city].index]
output_index = cosims_df.iloc[input_index[0][0]].sort_values(ascending = False).head(10)
cities.iloc[output_index.index]
# Out:
#              Country                       City  \
# 2318  United Kingdom                     London
# 2310  United Kingdom                    Glasgow
# 683          Denmark                 Copenhagen
# 1918          Russia                     Moscow
# 2357  United Kingdom                  Sheffield
# 2320  United Kingdom                      Leeds
# 2426   United States                    Chicago
# 2586   United States                  St. Louis
# 2005         Senegal                Saint Louis
# 2362  United Kingdom  London/Southwark-Lewisham
#
#                                              Understand  \
# 2318  "When a man is tired of London, he is tired of...
# 2310  Defining Glasgow[edit] The term “Glasgow” in i...
# 683   History[edit] If you had dropped by Copenhagen...
# 1918  Moscow is the financial and political center o...
# 2357  Sheffield is built on and in-between seven hil...
# 2320    Climate  Jan  Feb  Mar  Apr  May  Jun  Jul  ...
# 2426  Chicago was known as a fine place to find a wi...
# 2586  The city is named after King Louis IX of Franc...
# 2005  The city is named after King Louis IX of Franc...
# 2362  Southwark was one of the earliest extensions o...
#
#                                                  Get in  \
# 2318  By plane[edit] Due to London's huge global cit...
# 2310  By plane[edit] Glasgow is served by two main a...
# 683   By plane[edit] Copenhagen's Kastrup Airport [6...
# 1918  See Russia#Get in for visa requirements to Rus...
# 2357  By plane[edit] Doncaster Sheffield Airport, on...
# 2320  By plane[edit]  Leeds-Bradford International A...
# 2426  By plane[edit] Chicago (IATA: CHI for all airp...
# 2586  By car[edit] St. Louis can be accessed by Inte...
# 2005  By car[edit] St. Louis can be accessed by Inte...
# 2362  Much of South London is poorly served by the t...
#
#                                              Get around  \
# 2318  London has one of the most comprehensive publi...
# 2310  Strathclyde Partnership for Transport [81] (SP...
# 683   The two big hubs are Central Station (da: Hove...
# 1918  Walking[edit] Be wary of bicyclists on the sid...
# 2357  On foot in the City Centre[edit] Sheffield's c...
# 2320  On foot[edit] If just visiting the city centre...
# 2426  Navigating Chicago is easy. Block numbers are ...
# 2586  By train[edit] MetroLink, +1 314 231-2345 [44]...
# 2005  By train[edit] MetroLink, +1 314 231-2345 [44]...
# 2362                                                NaN
#
#                                                     See  \
# 2318      London with children London can be stressf...
# 2310  Architecture[edit] As befits a city that was a...
# 683   Complete listings can be found in the appropri...
# 1918  Museums and religious buildings[edit]  Red Squ...
# 2357  City Centre[edit] Sheffield city centre has un...
# 2320  City centre[edit] Although not considered a 't...
# 2426  Itineraries[edit]  Along the Magnificent Mile ...
# 2586   Anheuser-Busch Brewery, 1200 Lynch St, ☎ +1 3...
# 2005   Anheuser-Busch Brewery, 1200 Lynch St, ☎ +1 3...
# 2362   Crystal Palace Park,  (Crystal Palace Pk rail...
#
#                                                      Do  \
# 2318  London is a huge city, so all individual listi...
# 2310  There are many nightclubs, concerts and festiv...
# 683   Beach life[edit] In the inner harbour, water q...
# 1918  Moscow has many attractions, but many of them ...
# 2357  Sheffield is a vibrant, cosmopolitan city and ...
# 2320  Cinema[edit] Leeds holds two annual film festi...
# 2426  Shedd Aquarium (Shedd Aquarium), 1200 S. Lake ...
# 2586  America's Convention Center, [57]. Over 500,00...
# 2005  America's Convention Center, [57]. Over 500,00...
# 2362   The Shard, 93 Tooley Street (immediately adja...
#
#                                                     Buy  \
# 2318  Almost anything you could possibly want to buy...
# 2310  Glasgow has positioned itself as an upmarket r...
# 683   Strøget is one of the largest pedestrian malls...
# 1918  Credit card acceptance is widespread. ATMs are...
# 2357  Sheffield city centre is quite compact, so the...
# 2320       Opening Times  City centre - Mon-Sat 09:0...
# 2426  Whatever you need, you can buy it in Chicago, ...
# 2586  Delmar Loop, [85]. Funky, hip and great for pe...
# 2005  Delmar Loop, [85]. Funky, hip and great for pe...
# 2362   Bermondsey Antiques Market (New Caledonian Ma...
#
#                                                     Eat  \
# 2318     This guide uses the following price ranges ...
# 2310  The city has won the title "Curry Capital of B...
# 683   Please look for general restaurant listings in...
# 1918  Dining establishments in Moscow range from foo...
# 2357  There are many good, cheap places to eat in an...
# 2320     This guide uses the following price ranges ...
# 2426  Chicago is one of the great restaurant towns i...
# 2586  St. Louis has its very own magazine and accomp...
# 2005  St. Louis has its very own magazine and accomp...
# 2362  The area is home to two historic desserts, a p...
#
#                                                   Sleep  \
# 2318     This guide uses the following price ranges ...
# 2310  Glasgow, like any other major British city has...
# 683   Hotel listings are available in the appropriat...
# 1918  With the exception of some high-end hotels, al...
# 2357  City Centre[edit] City Crash Pad Serviced Apar...
# 2320  Budget[edit] There are currently no Youth Host...
# 2426  Chicago hosts many major conventions each year...
# 2586  St. Louis does have the host of usual Drury, M...
# 2005  St. Louis does have the host of usual Drury, M...
# 2362  Hotel Pasha, A rather unique place fronting Ca...
#
#                             ...                         Longitude  \
# 2318                        ...                               NaN
# 2310                        ...                               NaN
# 683                         ...                               NaN
# 1918                        ...                               NaN
# 2357                        ...                               NaN
# 2320                        ...                               NaN
# 2426                        ...                               NaN
# 2586                        ...                               NaN
# 2005                        ...                               NaN
# 2362                        ...                         -0.016667
#
#                       AccentCity  \
# 2318                         NaN
# 2310                         NaN
# 683                          NaN
# 1918                         NaN
# 2357                         NaN
# 2320                         NaN
# 2426                         NaN
# 2586                         NaN
# 2005                         NaN
# 2362  London Borough of Lewisham
#
#                                              See_tokens  \
# 2318  ['stressful', 'check', 'slightly', 'stressful'...
# 2310  ['architecture', 'beginning', 'fine', 'legacy'...
# 683   ['complete', 'appropriate', 'district', 'entra...
# 1918  ['religious', 'red', 'square', 'heart', 'desti...
# 2357  ['regeneration', 'past', 'twenty', 'plenty', '...
# 2320  ['considered', 'traditional', 'tourist', 'dest...
# 2426  ['magnificent', 'mile', 'night', 'shopping', '...
# 2586  ['brewery', 'lynch', 'mid', 'free', 'tour', 'f...
# 2005  ['brewery', 'lynch', 'mid', 'free', 'tour', 'f...
# 2362  ['crystal', 'palace', 'park', 'crystal', 'pala...
#
#                                               Do_tokens  \
# 2318  ['huge', 'individual', 'appropriate', 'distric...
# 2310  ['music', 'famous', 'music', 'scene', 'least',...
# 683   ['beach', 'life', 'inner', 'harbour', 'water',...
# 1918  ['friendly', 'non', 'speaker', 'language', 'el...
# 2357  ['vibrant', 'cosmopolitan', 'large', 'range', ...
# 2320  ['cinema', 'annual', 'film', 'increasingly', '...
# 2426  ['aquarium', 'aquarium', 'lake', 'shore', 'aqu...
# 2586  ['convention', 'center', 'square', 'exhibit', ...
# 2005  ['convention', 'center', 'square', 'exhibit', ...
# 2362  ['shard', 'immediately', 'adjacent', 'bridge',...
#
#                                           Pooled_tokens  \
# 2318  [stressful, check, slightly, stressful, huge, ...
# 2310  [architecture, beginning, fine, legacy, lavish...
# 683   [complete, appropriate, district, entrance, fr...
# 1918  [religious, red, square, heart, destination, s...
# 2357  [regeneration, past, twenty, plenty, offer, ho...
# 2320  [considered, traditional, tourist, destination...
# 2426  [magnificent, mile, night, shopping, food, ama...
# 2586  [brewery, lynch, mid, free, tour, free, beer, ...
# 2005  [brewery, lynch, mid, free, tour, free, beer, ...
# 2362  [crystal, palace, park, crystal, palace, rail,...
#
#                                       Understand_tokens  \
# 2318  ['man', 'tired', 'tired', 'life', 'life', 'aff...
# 2310  ['term', 'ambiguous', 'various', 'boundary', '...
# 683   ['history', 'eleventh', 'would', 'looking', 'q...
# 1918  ['financial', 'political', 'center', 'russia',...
# 2357  ['seven', 'thanks', 'landscape', 'industrial',...
# 2320  ['mar', 'daily', 'nightly', 'precipitation', '...
# 2426  ['known', 'fine', 'wild', 'onion', 'member', '...
# 2586  ['king', 'known', 'nickname', 'gateway', 'last...
# 2005  ['king', 'known', 'nickname', 'gateway', 'last...
# 2362  ['settlement', 'beyond', 'square', 'mile', 'ri...
#
#                                        Stay safe_tokens  \
# 2318  ['emergency', 'telephone', 'number', 'police',...
# 2310  ['emergency', 'contact', 'number', 'rest', 'ne...
# 683                                                  []
# 1918  ['low', 'crime', 'rate', 'large', 'metropolis'...
# 2357  ['rest', 'emergency', 'call', 'land', 'line', ...
# 2320  ['known', 'friendly', 'usual', 'degree', 'comm...
# 2426                                                 []
# 2586  ['dangerous', 'large', 'popular', 'downtown', ...
# 2005  ['dangerous', 'large', 'popular', 'downtown', ...
# 2362                                                 []
#
#                                           Pooled_string  \
# 2318  stressful check slightly stressful huge indivi...
# 2310  architecture beginning fine legacy lavish spec...
# 683   complete appropriate district entrance free we...
# 1918  religious red square heart destination surroun...
# 2357  regeneration past twenty plenty offer home com...
# 2320  considered traditional tourist destination ple...
# 2426  magnificent mile night shopping food amazing h...
# 2586  brewery lynch mid free tour free beer world bo...
# 2005  brewery lynch mid free tour free beer world bo...
# 2362  crystal palace park crystal palace rail statio...
#
#                                          Pooled_tokens2  \
# 2318  [stressful, check, slightly, stressful, huge, ...
# 2310  [architecture, beginning, fine, legacy, lavish...
# 683   [complete, appropriate, district, entrance, fr...
# 1918  [religious, red, square, heart, destination, s...
# 2357  [regeneration, past, twenty, plenty, offer, ho...
# 2320  [considered, traditional, tourist, destination...
# 2426  [magnificent, mile, night, shopping, food, ama...
# 2586  [brewery, lynch, mid, free, tour, free, beer, ...
# 2005  [brewery, lynch, mid, free, tour, free, beer, ...
# 2362  [crystal, palace, park, crystal, palace, rail,...
#
#                                          Pooled_string2
# 2318  stressful check slightly stressful huge indivi...
# 2310  architecture beginning fine legacy lavish spec...
# 683   complete appropriate district entrance free we...
# 1918  religious red square heart destination surroun...
# 2357  regeneration past twenty plenty offer home com...
# 2320  considered traditional tourist destination ple...
# 2426  magnificent mile night shopping food amazing h...
# 2586  brewery lynch mid free tour free beer world bo...
# 2005  brewery lynch mid free tour free beer world bo...
# 2362  crystal palace park crystal palace rail statio...
#
# [10 rows x 29 columns]

# %%
input_index = cities.index[cities['City']=='New York City'][0] # Get index of input
input_sims = pd.DataFrame(cosims_df.iloc[input_index]) # Get sims for input city
sims_sorted = input_sims.sort_values(by=input_index, ascending=False) # Sort sims
sims_top = sims_sorted.iloc[1:101]
top_index = sims_top.index
top_cities = cities.iloc[top_index][['City','Country','Lat','Lon','Pooled_tokens']]
top_cities
# Out:
#                     City         Country        Lat         Lon  \
# 2562           Rochester   United States  43.154784  -77.615555
# 2506         Los Angeles   United States  34.052234 -118.243683
# 2571       San Francisco   United States  37.774929 -122.419418
# 2402              Austin   United States  30.267153  -97.743057
# 2310             Glasgow  United Kingdom  55.833333   -4.250000
# 1957    Saint Petersburg          Russia  59.894444   30.264166
# 2428          Cincinnati   United States  39.162004  -84.456886
# 2399             Atlanta   United States  33.748995  -84.387985
# 1724              Bergen          Norway  42.493889  -88.865278
# 102             Brussels         Belgium  50.846598    4.352775
# 2005         Saint Louis         Senegal  16.017931  -16.489620
# 2586           St. Louis   United States  38.627273  -90.197891
# 2493         Kansas City   United States  39.099727  -94.578568
# 2102                Bâle     Switzerland  47.783333    3.366667
# 2423           Charlotte   United States  35.227087  -80.843124
# 683           Copenhagen         Denmark  55.677681   12.570934
# 2536               Omaha   United States  41.258610  -95.937790
# 284              Toronto          Canada  43.700114  -79.416306
# 2426             Chicago   United States  41.850033  -87.650055
# 2058              Madrid           Spain  40.416502   -3.702564
# 1656           Amsterdam     Netherlands  52.373084    4.899902
# 2547        Philadelphia   United States  39.952335  -75.163788
# 1628         Ulaanbaatar        Mongolia  47.916667  106.916667
# 800    Frankfurt am Main         Germany  50.116667    8.683333
# 808              Hamburg         Germany  53.550000   10.000000
# 885             Budapest         Hungary  47.500000   19.083334
# 2475            Hartford   United States  43.317778  -88.378889
# 736             Helsinki         Finland  60.175556   24.934166
# 735               Vantaa         Finland  60.296681   25.013809
# 2517           Milwaukee   United States  43.038902  -87.906471
# ...                  ...             ...        ...         ...
# 2461          Fort Worth   United States  32.725409  -97.320847
# 321              Beijing           China  39.907498  116.397224
# 2555               Provo   United States  40.233889 -111.657778
# 639   Santa Fe De Bogota        Colombia  16.311500  120.397000
# 100              Antwerp         Belgium  51.216667    4.416666
# 205              Resende          Brazil  41.105822   -7.966497
# 1725                Oslo          Norway  42.957222  129.993332
# 2017           Ljubljana        Slovenia  46.055278   14.514444
# 233                Sofia        Bulgaria  42.697513   23.324146
# 1527             Vilnius       Lithuania  54.683333   25.316668
# 52               Yerevan         Armenia  40.181111   44.513611
# 1918              Moscow          Russia  55.752222   37.615555
# 216            Sao Paulo          Brazil -23.547500  -46.636112
# 810             Hannover         Germany  52.370516    9.733221
# 2483          Huntsville   United States  38.254238  -85.759407
# 794              Dresden         Germany  51.050891   13.738318
# 2502             Lincoln   United States  40.800001  -96.666962
# 1410               Tokyo           Japan  35.689527  139.691681
# 275               Regina          Canada  50.450080 -104.617798
# 2433            Columbia   United States  39.961176  -82.998795
# 1472               Busan     South Korea  14.790833   44.454167
# 633             Medellín        Colombia  10.850000  -72.116667
# 344              Chengdu           China  30.666667  104.066666
# 1211              Tehran            Iran  35.671944   51.424446
# 719              Tallinn         Estonia  59.436958   24.753527
# 656               Zagreb         Croatia  45.800000   16.000000
# 862         Thessaloniki          Greece  40.640278   22.943890
# 2503         Little Rock   United States  34.476389  -79.403333
# 700                Quito         Ecuador  -0.216667  -78.500000
# 2409          Birmingham   United States  33.520661  -86.802490
#
#                                           Pooled_tokens
# 2562  [popular, river, gorge, certainly, worth, trip...
# 2506  [individual, district, lite, flight, lite, fli...
# 2571  [significant, detail, individual, district, li...
# 2402  [initially, drawn, hip, culture, live, music, ...
# 2310  [architecture, beginning, fine, legacy, lavish...
# 1957  [historic, center, saint, related, world, heri...
# 2428  [tower, observation, deck, vine, downtown, tow...
# 2399  [top, form, eclectic, mix, sure, something, ev...
# 1724  [number, surrounding, show, atmosphere, cultur...
# 102   [card, available, available, free, guidebook, ...
# 2005  [brewery, lynch, mid, free, tour, free, beer, ...
# 2586  [brewery, lynch, mid, free, tour, free, beer, ...
# 2493  [downtown, central, business, district, downto...
# 2102  [old, town, old, town, walkable, zoo, train, s...
# 2423  [itinerary, numerous, historic, scattered, thr...
# 683   [complete, appropriate, district, entrance, fr...
# 2536  [art, art, museum, work, degas, extensive, anc...
# 284   [individual, district, art, gallery, free, adm...
# 2426  [magnificent, mile, night, shopping, food, ama...
# 2058  [architecture, sol, sol, plaza, heart, hub, lo...
# 1656  [architecture, extensive, historic, registered...
# 2547  [multiple, benefit, admission, use, reduced, r...
# 1628  [capital, world, variety, ranging, historical,...
# 800   [historical, steg, bridge, center, old, number...
# 808   [central, railway, station, mainly, shopping, ...
# 885   [historic, parliament, national, parliament, d...
# 2475  [main, downtown, phone, public, art, museum, w...
# 736   [surrounded, sea, vast, archipelago, best, sum...
# 735   [surrounded, sea, vast, archipelago, best, sum...
# 2517  [bank, center, ave, state, bud, commissioner, ...
# ...                                                 ...
# 2461  [art, museum, camp, bowie, collection, mid, co...
# 321   [individual, important, landmark, square, dist...
# 2555  [young, university, university, avenue, genera...
# 639   [landmark, history, independence, took, distri...
# 100   [wapper, painter, peter, baroque, painter, mus...
# 205                               [modern, art, museum]
# 1725  [architecture, seem, dull, unlike, instance, c...
# 2017  [easiest, pleasant, way, reach, foot, except, ...
# 233   [ancient, throughout, center, administrative, ...
# 1527  [old, town, develop, extensively, middle, even...
# 52    [fortress, museum, nearly, old, fortress, esta...
# 1918  [religious, red, square, heart, destination, s...
# 216   [main, article, avenue, popular, pride, busine...
# 810   [great, garden, world, famous, baroque, copy, ...
# 2483  [widely, known, tourist, destination, doe, num...
# 794   [beautiful, light, spirited, summer, appreciat...
# 2502  [state, state, legislature, unique, unusual, u...
# 1410  [vast, array, agenda, imperial, palace, shrine...
# 275   [science, powerhouse, hundred, permanent, live...
# 2433  [garden, best, free, walk, fort, fort, major, ...
# 1472  [temple, line, station, great, large, complex,...
# 633   [pueblito, paisa, reconstruction, typical, tin...
# 344   [nice, expensive, tea, local, great, date, lat...
# 1211  [tower, symbol, commemorate, anniversary, empi...
# 719   [old, medieval, old, town, excellently, compac...
# 656   [upper, lower, grad, upper, town, grad, lower,...
# 862   [northernmost, western, standing, symbol, whit...
# 2503  [little, rock, eastern, edge, little, rock, sp...
# 700   [banco, central, adjacent, perhaps, renowned, ...
# 2409  [men, hall, fame, drive, university, midnight,...
#
# [100 rows x 5 columns]

# %%
cities.shape
# Out:
# (2671, 29)

# %% [markdown]
# # Creating narrow df for SQL server

# %%
# Keeo only necessary columns
cities_narrow = cities[['Country','City','Lat','Lon']]
cities_narrow.head()
# Out:
#        Country       City        Lat        Lon
# 0  Afghanistan      Herat  34.340000  62.189999
# 1  Afghanistan      Kabul  34.516667  69.183334
# 2  Afghanistan  Jalalabad  34.420000  70.449997
# 3  Afghanistan   Kandahar  31.610000  65.699997
# 4  Afghanistan     Kunduz  36.720000  68.860001

# %%
# Sorted index of top 10 similar cities
idx = np.argsort(-cosims_df, axis=1)
idx = idx.iloc[:,1:11]
idx.columns = ['s1','s2','s3','s4','s5','s6','s7','s8','s9','s10']
idx.head()
# Out:
#      s1    s2    s3    s4    s5    s6    s7    s8    s9   s10
# 0  1209  2624  1201  2210   599  1219  1055   962  1754  1232
# 1   233  1744  1742  1628  2607  2310  1746   885  2362  2015
# 2  1062  2637   995  1754     1  1193  1072  1099   991  1211
# 3  2000  1741  1220  1037  1980   929  2628  1133  1111  1002
# 4     0  1776  1777  1778  1779  1780  1781  1782  1783  1784

# %%
cities_narrow_top10 = pd.concat([cities_narrow, idx],axis=1)

# %%
cities_narrow_top10.head()
# Out:
#        Country       City        Lat        Lon    s1    s2    s3    s4    s5  \
# 0  Afghanistan      Herat  34.340000  62.189999  1209  2624  1201  2210   599
# 1  Afghanistan      Kabul  34.516667  69.183334   233  1744  1742  1628  2607
# 2  Afghanistan  Jalalabad  34.420000  70.449997  1062  2637   995  1754     1
# 3  Afghanistan   Kandahar  31.610000  65.699997  2000  1741  1220  1037  1980
# 4  Afghanistan     Kunduz  36.720000  68.860001     0  1776  1777  1778  1779
#
#      s6    s7    s8    s9   s10
# 0  1219  1055   962  1754  1232
# 1  2310  1746   885  2362  2015
# 2  1193  1072  1099   991  1211
# 3   929  2628  1133  1111  1002
# 4  1780  1781  1782  1783  1784

# %%
# Save file to be used by server
cities_narrow_top10.to_csv('cities_narrow.csv')

# %%
# Code to be used from userver

# %%
input_index
# Out:
# 2527

# %%
# Get index table
idx = cities_narrow_top10.loc[:,'s1':'s10']
idx.head()
# Out:
#      s1    s2    s3    s4    s5    s6    s7    s8    s9   s10
# 0  1209  2624  1201  2210   599  1219  1055   962  1754  1232
# 1   233  1744  1742  1628  2607  2310  1746   885  2362  2015
# 2  1062  2637   995  1754     1  1193  1072  1099   991  1211
# 3  2000  1741  1220  1037  1980   929  2628  1133  1111  1002
# 4     0  1776  1777  1778  1779  1780  1781  1782  1783  1784

# %%
cities_narrow_top10.iloc[idx.iloc[input_index]]
# Out:
#              Country              City        Lat         Lon    s1    s2  \
# 2562   United States         Rochester  43.154784  -77.615555  2506  2517
# 2506   United States       Los Angeles  34.052234 -118.243683  2562  2428
# 2571   United States     San Francisco  37.774929 -122.419418  2506  2579
# 2402   United States            Austin  30.267153  -97.743057  2562  2506
# 2310  United Kingdom           Glasgow  55.833333   -4.250000  2274  2375
# 1957          Russia  Saint Petersburg  59.894444   30.264166  1918   885
# 2428   United States        Cincinnati  39.162004  -84.456886  2562  2506
# 2399   United States           Atlanta  33.748995  -84.387985  2506  2549
# 1724          Norway            Bergen  42.493889  -88.865278   736   735
# 102          Belgium          Brussels  50.846598    4.352775   755   105
#
#         s3    s4    s5    s6    s7    s8    s9   s10
# 2562  2428  2402   253  2444   275  2005  2586   290
# 2506  2571  2536  2579  2586  2005  2402  2549  2517
# 2571  2562  2527  2372  2570  1724  2005  2586  2402
# 2402  2517  2443  2527   270   847  2428  2423  2579
# 2310  2327  2357  2318  2320   800  1225  2362  2334
# 1957  2008  1523   808  1724  2527  1979  1628   800
# 2428  2547  2005  2586  2536  2517  2444  2424  2607
# 2399  2428  2005  2586  2562  2527  2536  2572  2579
# 1724   893   885  2089   102   808   800  1656   683
# 102    885  1656   800  1724   735   736  1675  2058
