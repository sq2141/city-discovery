# %%
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from IPython.display import clear_output
from matplotlib import pyplot as plt

# %%
# Load city names
cities_names = pd.read_csv('wikitravel_city_URLs.csv', index_col = 0)
cities_names.columns = ['Country','City','URL']
cities_names.head()
# Out:
#        Country       City                          URL
# 0  Afghanistan      Herat      wikitravel.org/en/Herat
# 1  Afghanistan      Kabul      wikitravel.org/en/Kabul
# 2  Afghanistan  Jalalabad  wikitravel.org/en/Jalalabad
# 3  Afghanistan   Kandahar   wikitravel.org/en/Kandahar
# 4  Afghanistan     Kunduz     wikitravel.org/en/Kunduz

# %%
# Load city soups
cities_soups = pd.read_csv('data/cities_soups.csv', index_col = 0)
cities_soups.columns = ['Soup']
cities_soups.head()
# Out:
#                                                 Soup
# 0  <!DOCTYPE html>\n<html class="client-nojs" dir...
# 1  <!DOCTYPE html>\n<html class="client-nojs" dir...
# 2  <!DOCTYPE html>\n<html class="client-nojs" dir...
# 3  <!DOCTYPE html>\n<html class="client-nojs" dir...
# 4  <!DOCTYPE html>\n<html class="client-nojs" dir...

# %%
bad_format_cities = [921,2032] # cities to skip
understand_holder = []
getin_holder = []
getaround_holder = []
see_holder = []
do_holder = []
buy_holder = []
eat_holder = []
sleep_holder = []
cope_holder = []
staysafe_holder = []
getout_holder = []

# Loop through cities
for n, city_soup in enumerate(cities_soups.values):
    print(n)
    clear_output(wait=True)
    
    # Skip cities with bad data
    if n in bad_format_cities:
        understand_holder.append('')
        getin_holder.append('')
        getaround_holder.append('')
        see_holder.append('')
        do_holder.append('')
        buy_holder.append('')
        eat_holder.append('')
        sleep_holder.append('')
        cope_holder.append('')
        staysafe_holder.append('')
        getout_holder.append('')
        continue
    
    soup_str = city_soup[0]
    soup = BeautifulSoup(soup_str, "html5lib")
    body = soup.find('body').find('div',{'id':'content'}).find('div',{'id':'bodyContent'}).find('div',{'id':'mw-content-text'})
    body_table = body.table.tbody.tr.find('td',{'valign':'top'}).find('div',{'class':'mw-parser-output'})
    
    understand = []
    understand_seed = body_table.find('span',{'id':'Understand'})
    if understand_seed is not None:
        for item in understand_seed.parent.nextSiblingGenerator():
            if (item.name == "h2"): # Complete loop once reaches end of section
                break
            if (item.name == 'div'): # Skip pics
                continue
            if hasattr(item, "text"):
                understand.append(item.text.replace('\n', ' '))         
    understand_holder.append(' '.join(understand)) # Append to holder for all cities
    
    getin = []
    getin_seed = body_table.find('span',{'id':'Get_in'})
    if getin_seed is not None:
        for item in getin_seed.parent.nextSiblingGenerator():
            if (item.name == "h2"): # Complete loop once reaches end of section
                break
            if (item.name == 'div'): # Skip pics
                continue
            if hasattr(item, "text"):
                getin.append(item.text.replace('\n', ' '))         
    getin_holder.append(' '.join(getin)) # Append to holder for all cities
    
    getaround = []
    getaround_seed = body_table.find('span',{'id':'Get_around'})
    if getaround_seed is not None:
        for item in getaround_seed.parent.nextSiblingGenerator():
            if (item.name == "h2"): # Complete loop once reaches end of section
                break
            if (item.name == 'div'): # Skip pics
                continue
            if hasattr(item, "text"):
                getaround.append(item.text.replace('\n', ' '))         
    getaround_holder.append(' '.join(getaround)) # Append to holder for all cities
    
    see = []
    see_seed = body_table.find('span',{'id':'See'})
    if see_seed is not None:
        for item in see_seed.parent.nextSiblingGenerator():
            if (item.name == "h2"): # Complete loop once reaches end of section
                break
            if (item.name == 'div'): # Skip pics
                continue
            if hasattr(item, "text"):
                see.append(item.text.replace('\n', ' '))         
    see_holder.append(' '.join(see)) # Append to holder for all cities
    
    do = []
    do_seed = body_table.find('span',{'id':'Do'})
    if do_seed is not None:
        for item in do_seed.parent.nextSiblingGenerator():
            if (item.name == "h2"): # Complete loop once reaches end of section
                break
            if (item.name == 'div'): # Skip pics
                continue
            if hasattr(item, "text"):
                do.append(item.text.replace('\n', ' '))         
    do_holder.append(' '.join(do)) # Append to holder for all cities
    
    buy = []
    buy_seed = body_table.find('span',{'id':'Buy'})
    if buy_seed is not None:
        for item in buy_seed.parent.nextSiblingGenerator():
            if (item.name == "h2"): # Complete loop once reaches end of section
                break
            if (item.name == 'div'): # Skip pics
                continue
            if hasattr(item, "text"):
                buy.append(item.text.replace('\n', ' '))         
    buy_holder.append(' '.join(buy)) # Append to holder for all cities
    
    eat = []
    eat_seed = body_table.find('span',{'id':'Eat'})
    if eat_seed is not None:
        for item in eat_seed.parent.nextSiblingGenerator():
            if (item.name == "h2"): # Complete loop once reaches end of section
                break
            if (item.name == 'div'): # Skip pics
                continue
            if hasattr(item, "text"):
                eat.append(item.text.replace('\n', ' '))         
    eat_holder.append(' '.join(eat)) # Append to holder for all cities
    
    sleep = []
    sleep_seed = body_table.find('span',{'id':'Sleep'})
    if sleep_seed is not None:
        for item in sleep_seed.parent.nextSiblingGenerator():
            if (item.name == "h2"): # Complete loop once reaches end of section
                break
            if (item.name == 'div'): # Skip pics
                continue
            if hasattr(item, "text"):
                sleep.append(item.text.replace('\n', ' '))         
    sleep_holder.append(' '.join(sleep)) # Append to holder for all cities
    
    cope = []
    cope_seed = body_table.find('span',{'id':'Cope'})
    if cope_seed is not None:
        for item in cope_seed.parent.nextSiblingGenerator():
            if (item.name == "h2"): # Complete loop once reaches end of section
                break
            if (item.name == 'div'): # Skip pics
                continue
            if hasattr(item, "text"):
                cope.append(item.text.replace('\n', ' '))         
    cope_holder.append(' '.join(cope)) # Append to holder for all cities
    
    staysafe = []
    staysafe_seed = body_table.find('span',{'id':'Stay_safe'})
    if staysafe_seed is not None:
        for item in staysafe_seed.parent.nextSiblingGenerator():
            if (item.name == "h2"): # Complete loop once reaches end of section
                break
            if (item.name == 'div'): # Skip pics
                continue
            if hasattr(item, "text"):
                staysafe.append(item.text.replace('\n', ' '))         
    staysafe_holder.append(' '.join(staysafe)) # Append to holder for all cities
    
    getout = []
    getout_seed = body_table.find('span',{'id':'Get_out'})
    if getout_seed is not None:
        for item in getout_seed.parent.nextSiblingGenerator():
            if (item.name == "h2"): # Complete loop once reaches end of section
                break
            if (item.name == 'div'): # Skip pics
                continue
            if hasattr(item, "text"):
                getout.append(item.text.replace('\n', ' '))         
    getout_holder.append(' '.join(getout)) # Append to holder for all cities
# Out:
# 2692

# %%
cities_desc = pd.DataFrame({'Understand': understand_holder,
                     'Get in': getin_holder,
                     'Get around': getaround_holder,
                     'See': see_holder,
                     'Do': do_holder,
                     'Buy': buy_holder,
                     'Eat': eat_holder,
                     'Sleep': sleep_holder,
                     'Cope': cope_holder,
                     'Stay safe': staysafe_holder,
                     'Get out': getout_holder})

# %%
cities_desc.head()
# Out:
#                                           Understand  \
# 0  Herat is the second largest city in Afghanista...
# 1  Kabul is a very historic city of the region th...
# 2
# 3  Kandahār or Qandahār (Pashto: کندهار ) (Persia...
# 4
#
#                                               Get in  \
# 0  The Herat International Airport is situated 15...
# 1  By plane[edit] Kabul International Airport (IA...
# 2  Jalalabad is on the major highway that links K...
# 3  By plane[edit] Kandahar International Airport ...
# 4  Most visitors will arrive by road from Pol-e K...
#
#                                           Get around  \
# 0
# 1  Maps of Kabul are available from Afghanistan I...
# 2
# 3
# 4  The city is fairly small.  The local roads, li...
#
#                                                  See  \
# 0   Ghala Ekhteyaradin, Takht Safar, Bagh Milat, ...
# 1   Bagh-e Babur (Gardens of Babur). The gardens ...
# 2   The large reservoir near Sarobi. This is loca...
# ...

# %%
cities_df = pd.concat([cities_names[['Country','City']], cities_desc], axis=1)

# %%
cities_df.head()
# Out:
#        Country       City                                         Understand  \
# 0  Afghanistan      Herat  Herat is the second largest city in Afghanista...
# 1  Afghanistan      Kabul  Kabul is a very historic city of the region th...
# 2  Afghanistan  Jalalabad
# 3  Afghanistan   Kandahar  Kandahār or Qandahār (Pashto: کندهار ) (Persia...
# 4  Afghanistan     Kunduz
#
#                                               Get in  \
# 0  The Herat International Airport is situated 15...
# 1  By plane[edit] Kabul International Airport (IA...
# 2  Jalalabad is on the major highway that links K...
# 3  By plane[edit] Kandahar International Airport ...
# 4  Most visitors will arrive by road from Pol-e K...
#
#                                           Get around  \
# 0
# 1  Maps of Kabul are available from Afghanistan I...
# 2
# 3
# 4  The city is fairly small.  The local roads, li...
#
#                                                  See  \
# ...

# %%
cities_df.to_csv('cities_df.csv')

# %%
# Number of cities with no data in specific sections
cities_df.agg(lambda x:list(x).count(''))
# Out:
# Country          0
# City             0
# Understand    1105
# Get in         363
# Get around     805
# See            416
# Do             810
# Buy            917
# Eat            592
# Sleep          517
# Cope          2145
# Stay safe     1912
# Get out        202
# dtype: int64

# %%
# Distribution if text length for specific sections of the wiki
plt.hist(cities_df['Do'].apply(len).values, bins=20);
