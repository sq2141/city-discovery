# %%
import pandas as pd
import numpy as np

import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import FreqDist
# Out:
# /home/sam/anaconda3/envs/insight/lib/python3.7/site-packages/sklearn/utils/__init__.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence

# %%
cities_raw = pd.read_csv('cities_geo2_df.csv', index_col=0)
cities = cities_raw.loc[:,:'Get out'] # Just text portions of the df

# %%
cities.head()
# Out:
#        Country       City                                         Understand  \
# 0  Afghanistan      Herat  Herat is the second largest city in Afghanista...
# 1  Afghanistan      Kabul  Kabul is a very historic city of the region th...
# 2  Afghanistan  Jalalabad                                                NaN
# 3  Afghanistan   Kandahar  Kandahār or Qandahār (Pashto: کندهار ) (Persia...
# 4  Afghanistan     Kunduz                                                NaN
#
#                                               Get in  \
# 0  The Herat International Airport is situated 15...
# 1  By plane[edit] Kabul International Airport (IA...
# 2  Jalalabad is on the major highway that links K...
# 3  By plane[edit] Kandahar International Airport ...
# 4  Most visitors will arrive by road from Pol-e K...
#
#                                           Get around  \
# 0                                                NaN
# 1  Maps of Kabul are available from Afghanistan I...
# 2                                                NaN
# 3                                                NaN
# 4  The city is fairly small.  The local roads, li...
#
#                                                  See  \
# 0   Ghala Ekhteyaradin, Takht Safar, Bagh Milat, ...
# 1   Bagh-e Babur (Gardens of Babur). The gardens ...
# 2   The large reservoir near Sarobi. This is loca...
# 3   Kandahar Museum,  (Western end of the Eidgah ...
# 4               There's not much for tourists here.
#
#                                                   Do  \
# 0    Take a shower in the huge subterranean Hammams.
# 1   Kabul Wall. A pleasant hike with rewarding vi...
# 2    Go fishing along the river side.  Go swimming .
# 3                                                NaN
# 4                                                NaN
#
#                                                  Buy  \
# 0   There are several antique shops on the north ...
# 1  The Share-e Naw area has some shops.   The Kab...
# 2   Handi Craft Handicraft is one of most famous ...
# 3  Afghanistan International Bank (AIB), Kabul Ba...
# 4                                                NaN
#
#                                                  Eat  \
# 0  Herat has a mixture of traditional and modern ...
# 1  The once thriving restaurant scene in Kabul ha...
# 2   Pakora go for special “Pakora” Food in Hindu ...
# 3  There are plenty of food choices in Kandahar, ...
# 4  The usual Afghan fare - kebab or lamb with ric...
#
#                                                Sleep  \
# 0  Budget[edit]  Mowafaq Hotel, northeast corner ...
# 1  Kabul is not a cheap place to stay, principall...
# 2   The government hotel Spingar is on the easter...
# 3  Budget[edit]  Armani Hotel,  (Two miles from c...
# 4                                                NaN
#
#                                                 Cope  \
# 0                                                NaN
# 1  Read the Scene magazine for restaurant reviews...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Stay safe  \
# 0  Herat is one of the safer cities in Afghanista...
# 1  Kabul is generally considered one of the safer...
# 2                                                NaN
# 3  As of 2013, the city centre of Kandahar is qui...
# 4                                                NaN
#
#                                              Get out
# 0  Chisht-i-Sharif is some 177 km from Herat city...
# 1  Most expats take any opportunity they can to l...
# 2    This article is an outline and needs more co...
# 3  Kabul Helmand Harat Zabul Spin Boldak (Spin Bu...
# 4      This article is an outline and needs more ...

# %%
# Run once
# nltk.download('wordnet')
# nltk.download('stopwords')
# nltk.download('averaged_perceptron_tagger')

# %%
tokenizer = RegexpTokenizer(r'\w+') # retains alphanumeric character
lmtzr = WordNetLemmatizer()
cached_stop_words = stopwords.words("english")

# %%
def lemmatize_dropstop_words(text): 
    return [lmtzr.lemmatize(word) for word in text if lmtzr.lemmatize(word) not in cached_stop_words]

# %%
cities = cities.replace(np.nan, '', regex=True)

# %%
cities.head()
# Out:
#        Country       City                                         Understand  \
# 0  Afghanistan      Herat  Herat is the second largest city in Afghanista...
# 1  Afghanistan      Kabul  Kabul is a very historic city of the region th...
# 2  Afghanistan  Jalalabad
# 3  Afghanistan   Kandahar  Kandahār or Qandahār (Pashto: کندهار ) (Persia...
# 4  Afghanistan     Kunduz
#
#                                               Get in  \
# 0  The Herat International Airport is situated 15...
# 1  By plane[edit] Kabul International Airport (IA...
# 2  Jalalabad is on the major highway that links K...
# 3  By plane[edit] Kandahar International Airport ...
# 4  Most visitors will arrive by road from Pol-e K...
#
#                                           Get around  \
# 0
# 1  Maps of Kabul are available from Afghanistan I...
# 2
# 3
# 4  The city is fairly small.  The local roads, li...
#
#                                                  See  \
# 0   Ghala Ekhteyaradin, Takht Safar, Bagh Milat, ...
# 1   Bagh-e Babur (Gardens of Babur). The gardens ...
# 2   The large reservoir near Sarobi. This is loca...
# 3   Kandahar Museum,  (Western end of the Eidgah ...
# 4               There's not much for tourists here.
#
#                                                   Do  \
# 0    Take a shower in the huge subterranean Hammams.
# 1   Kabul Wall. A pleasant hike with rewarding vi...
# 2    Go fishing along the river side.  Go swimming .
# 3
# 4
#
#                                                  Buy  \
# 0   There are several antique shops on the north ...
# 1  The Share-e Naw area has some shops.   The Kab...
# 2   Handi Craft Handicraft is one of most famous ...
# 3  Afghanistan International Bank (AIB), Kabul Ba...
# 4
#
#                                                  Eat  \
# 0  Herat has a mixture of traditional and modern ...
# 1  The once thriving restaurant scene in Kabul ha...
# 2   Pakora go for special “Pakora” Food in Hindu ...
# 3  There are plenty of food choices in Kandahar, ...
# 4  The usual Afghan fare - kebab or lamb with ric...
#
#                                                Sleep  \
# 0  Budget[edit]  Mowafaq Hotel, northeast corner ...
# 1  Kabul is not a cheap place to stay, principall...
# 2   The government hotel Spingar is on the easter...
# 3  Budget[edit]  Armani Hotel,  (Two miles from c...
# 4
#
#                                                 Cope  \
# 0
# 1  Read the Scene magazine for restaurant reviews...
# 2
# 3
# 4
#
#                                            Stay safe  \
# 0  Herat is one of the safer cities in Afghanista...
# 1  Kabul is generally considered one of the safer...
# 2
# 3  As of 2013, the city centre of Kandahar is qui...
# 4
#
#                                              Get out  \
# 0  Chisht-i-Sharif is some 177 km from Herat city...
# 1  Most expats take any opportunity they can to l...
# 2    This article is an outline and needs more co...
# 3  Kabul Helmand Harat Zabul Spin Boldak (Spin Bu...
# 4      This article is an outline and needs more ...
#
#                                    Understand_tokens
# 0  [herat, second, largest, city, afghanistan, lo...
# 1  [kabul, historic, city, region, wa, built, alm...
# 2                                                 []
# 3  [kandahār, qandahār, pashto, کندهار, persian, ...
# 4                                                 []

# %%
# Tokenize, lemmatize
cities['Understand_tokens'] = cities['Understand'].str.lower().apply(tokenizer.tokenize).apply(lemmatize_dropstop_words)
cities['See_tokens'] = cities['See'].str.lower().apply(tokenizer.tokenize).apply(lemmatize_dropstop_words)
cities['Do_tokens'] = cities['Do'].str.lower().apply(tokenizer.tokenize).apply(lemmatize_dropstop_words)
cities['Buy_tokens'] = cities['Buy'].str.lower().apply(tokenizer.tokenize).apply(lemmatize_dropstop_words)
cities['Eat_tokens'] = cities['Eat'].str.lower().apply(tokenizer.tokenize).apply(lemmatize_dropstop_words)

# %%
cities.head()
# Out:
#        Country       City                                         Understand  \
# 0  Afghanistan      Herat  Herat is the second largest city in Afghanista...
# 1  Afghanistan      Kabul  Kabul is a very historic city of the region th...
# 2  Afghanistan  Jalalabad
# 3  Afghanistan   Kandahar  Kandahār or Qandahār (Pashto: کندهار ) (Persia...
# 4  Afghanistan     Kunduz
#
#                                               Get in  \
# 0  The Herat International Airport is situated 15...
# 1  By plane[edit] Kabul International Airport (IA...
# 2  Jalalabad is on the major highway that links K...
# 3  By plane[edit] Kandahar International Airport ...
# 4  Most visitors will arrive by road from Pol-e K...
#
#                                           Get around  \
# 0
# 1  Maps of Kabul are available from Afghanistan I...
# 2
# 3
# 4  The city is fairly small.  The local roads, li...
#
#                                                  See  \
# 0   Ghala Ekhteyaradin, Takht Safar, Bagh Milat, ...
# 1   Bagh-e Babur (Gardens of Babur). The gardens ...
# 2   The large reservoir near Sarobi. This is loca...
# 3   Kandahar Museum,  (Western end of the Eidgah ...
# 4               There's not much for tourists here.
#
#                                                   Do  \
# 0    Take a shower in the huge subterranean Hammams.
# 1   Kabul Wall. A pleasant hike with rewarding vi...
# 2    Go fishing along the river side.  Go swimming .
# 3
# 4
#
#                                                  Buy  \
# 0   There are several antique shops on the north ...
# 1  The Share-e Naw area has some shops.   The Kab...
# 2   Handi Craft Handicraft is one of most famous ...
# 3  Afghanistan International Bank (AIB), Kabul Ba...
# 4
#
#                                                  Eat  \
# 0  Herat has a mixture of traditional and modern ...
# 1  The once thriving restaurant scene in Kabul ha...
# 2   Pakora go for special “Pakora” Food in Hindu ...
# 3  There are plenty of food choices in Kandahar, ...
# 4  The usual Afghan fare - kebab or lamb with ric...
#
#                                                Sleep  \
# 0  Budget[edit]  Mowafaq Hotel, northeast corner ...
# 1  Kabul is not a cheap place to stay, principall...
# 2   The government hotel Spingar is on the easter...
# 3  Budget[edit]  Armani Hotel,  (Two miles from c...
# 4
#
#                                                 Cope  \
# 0
# 1  Read the Scene magazine for restaurant reviews...
# 2
# 3
# 4
#
#                                            Stay safe  \
# 0  Herat is one of the safer cities in Afghanista...
# 1  Kabul is generally considered one of the safer...
# 2
# 3  As of 2013, the city centre of Kandahar is qui...
# 4
#
#                                              Get out  \
# 0  Chisht-i-Sharif is some 177 km from Herat city...
# 1  Most expats take any opportunity they can to l...
# 2    This article is an outline and needs more co...
# 3  Kabul Helmand Harat Zabul Spin Boldak (Spin Bu...
# 4      This article is an outline and needs more ...
#
#                                    Understand_tokens  \
# 0  [herat, second, largest, city, afghanistan, lo...
# 1  [kabul, historic, city, region, wa, built, alm...
# 2                                                 []
# 3  [kandahār, qandahār, pashto, کندهار, persian, ...
# 4                                                 []
#
#                                           See_tokens  \
# 0  [ghala, ekhteyaradin, takht, safar, bagh, mila...
# 1  [bagh, e, babur, garden, babur, garden, surrou...
# 2  [large, reservoir, near, sarobi, located, way,...
# 3  [kandahar, museum, western, end, eidgah, durwa...
# 4                                    [much, tourist]
#
#                                            Do_tokens  \
# 0        [take, shower, huge, subterranean, hammams]
# 1  [kabul, wall, pleasant, hike, rewarding, view,...
# 2    [go, fishing, along, river, side, go, swimming]
# 3                                                 []
# 4                                                 []
#
#                                           Buy_tokens  \
# 0  [several, antique, shop, north, side, mosque, ...
# 1  [share, e, naw, area, ha, shop, kabul, city, c...
# 2  [handi, craft, handicraft, one, famous, produc...
# 3  [afghanistan, international, bank, aib, kabul,...
# 4                                                 []
#
#                                           Eat_tokens
# 0  [herat, ha, mixture, traditional, modern, food...
# 1  [thriving, restaurant, scene, kabul, ha, suffe...
# 2  [pakora, go, special, pakora, food, hindu, str...
# 3  [plenty, food, choice, kandahar, however, serf...
# 4  [usual, afghan, fare, kebab, lamb, rice, river...

# %%
# Most common words
words = []
for sublist in cities['See_tokens']:
    for item in sublist:
        words.append(item)
        
fdist = FreqDist(words)
fdist.most_common(50)
# Out:
# [('museum', 9761),
#  ('edit', 9639),
#  ('city', 6420),
#  ('park', 5681),
#  ('wa', 5456),
#  ('one', 4413),
#  ('ha', 4158),
#  ('also', 3997),
#  ('art', 3744),
#  ('building', 3690),
#  ('temple', 3563),
#  ('1', 3229),
#  ('located', 2933),
#  ('house', 2858),
#  ('church', 2801),
#  ('built', 2800),
#  ('area', 2800),
#  ('street', 2716),
#  ('old', 2699),
#  ('place', 2636),
#  ('free', 2614),
#  ('garden', 2377),
#  ('00', 2338),
#  ('many', 2325),
#  ('see', 2259),
#  ('century', 2224),
#  ('2', 2122),
#  ('well', 2083),
#  ('bus', 2076),
#  ('5', 2068),
#  ('take', 2055),
#  ('town', 2025),
#  ('de', 1998),
#  ('st', 1996),
#  ('10', 1980),
#  ('open', 1970),
#  ('world', 1966),
#  ('year', 1901),
#  ('around', 1900),
#  ('center', 1879),
#  ('history', 1827),
#  ('station', 1804),
#  ('view', 1753),
#  ('day', 1751),
#  ('road', 1743),
#  ('collection', 1741),
#  ('small', 1738),
#  ('3', 1730),
#  ('square', 1713),
#  ('tour', 1700)]

# %%
# NLP
